# %% [markdown]
# # Working with Python Files
#
# One of the challenges in this program is integrating content that is written in code, with content that is hosted in bCourses. In this notebook, we demonstrate how to achive these aims.

# %%
import pandas as pd 
import numpy as np 
import matplotlib 
import seaborn as sns

# %% [markdown]
# ## Everybody Loves a Good Medical Story
#
# So, in this we plot something about brain activity. We're honestly, not really sure what we're showing.

# %%
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ## Questions to Answer
#
# 1. What do you think of this?
# 2. Are we able to modify this?
